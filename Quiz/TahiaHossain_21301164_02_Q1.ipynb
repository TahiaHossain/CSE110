# %%
number=int(input("Please enter a number: "))

for index in range (number) :
  if int(index)+1 > int(index) :
    print(number, "is a blissful number")
    break
  else :
    print(number, "is a normal number")
# Out:
# Please enter a number: 11
# 11 is a blissful number
