# %% [markdown]
# 𝗤𝘂𝗲𝘀𝘁𝗶𝗼𝗻:
# Assume on a planet called “Chocolatey”, 1 month = 20 days and 1 year = 240 days = 12 months.  Write a function Days that takes 2 arguments: a start date and the last date. Then calculates the number of days between these two dates(inclusive) and returns it to the function call.
# Assume, the start and last date will be given in dd/mm/yyyy format.
#
# ================================
# Function Call1:
# function_name("3/8/2018", "12/12/2020")
# Sample Output1:
# 570
# ================================
# Function Call2:
# function_name("3/8/2020", "12/12/2020")
# Sample Output2:
# 90
# ================================
# Function Call3:
# function_name("3/8/2018", "3/9/2020")
# Sample Output3:
# 501
# ================================
# Function Call4:
# function_name("3/8/2018", "10/8/2020")
# Sample Output4:
# 488

# %%
def function_name (date,time) :
  b = "23-11-1995"
  day1,month1,year1 = list(map(int,b.split("-")))

today = "6-9-2021"
day2,month2,year2 = list(map(int,today.split("-")))

if day2<day1 :
  day2+=30
  month2-=1

if month2<month1 :
  month2 += 12
  year2 -= 1

print(year2-year1,month2-month1,day2-day1)
print(function_name(date,time))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-306f0a5dcc74> in <module>()
#       6 day2,month2,year2 = list(map(int,today.split("-")))
#       7
# ----> 8 if day2<day1 :
#       9   day2+=30
#      10   month2-=1
#
# NameError: name 'day1' is not defined

# %%
def function_day (start_date, end_date) :

  date1 = "3/8/2018".split("/")

  day1 = int(date1[0])
  month1 = int(date1[1])
  year1 = int(date1[2])

  day2 = int(date1[0])
  month2 = int(date1[1])
  year2 = int(date1[2])

  difference = day2 - day1 + month2*30 - month1*1 + year2*365 - year1*365
  return difference

print(function_day(input(),input()))
# Out:
# 3/8/2018
# 12/12/2020
# 232

# %%
from datetime import datetime as dt

def days (a,b) :
  a_date = dt.strptimr()
